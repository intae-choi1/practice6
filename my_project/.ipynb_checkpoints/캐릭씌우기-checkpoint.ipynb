# %% [markdown]
# # 프로젝트: 얼굴에 캐릭 씌우기

# %% [markdown]
# ### face detection vs face recognition
# ### 얼굴 찾기 vs 누구 얼굴인지 알아내기

# %%
import cv2
import mediapipe as mp

# %%
# 얼굴을 찾고, 찾은 얼굴에 표시를 하기 위한 변수 정의
mp_face_detection = mp.solutions.face_detection # 얼굴 검출은 위한 face detection 모듈
mp_drawing = mp.solutions.drawing_utils # 얼굴의 특징을 그리기 위한 drawing utils 모듈

# %%
# For static images:
# IMAGE_FILES = []
# with mp_face_detection.FaceDetection(
#     model_selection=1, min_detection_confidence=0.5) as face_detection:
#   for idx, file in enumerate(IMAGE_FILES):
#     image = cv2.imread(file)
#     # Convert the BGR image to RGB and process it with MediaPipe Face Detection.
#     results = face_detection.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

#     # Draw face detections of each face.
#     if not results.detections:
#       continue
#     annotated_image = image.copy()
#     for detection in results.detections:
#       print('Nose tip:')
#       print(mp_face_detection.get_key_point(
#           detection, mp_face_detection.FaceKeyPoint.NOSE_TIP))
#       mp_drawing.draw_detection(annotated_image, detection)
#     cv2.imwrite('/tmp/annotated_image' + str(idx) + '.png', annotated_image)

# %%
# For webcam input:
cap = cv2.VideoCapture(0)
# cap = cv2.VideoCapture('face_video.mp4')

# model selection : 0 or 1
# 0: 카메라로부터 2m 이내, 1: 카메라로부터 5m 이내에 적합
# min_detection_confidence(≒threshold) : 몇퍼 이상이면 얼굴
with mp_face_detection.FaceDetection(
    model_selection=0, min_detection_confidence=0.95) as face_detection:
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")
            # If loading a video, use 'break' instead of 'continue'.
            break

        # To improve performance, optionally mark the image as not writeable to
        # pass by reference.
        image.flags.writeable = False
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = face_detection.process(image)

        # Draw the face detection annotations on the image.
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.detections:
            for detection in results.detections:
                mp_drawing.draw_detection(image, detection)
                print(detection)
        # Flip the image horizontally for a selfie-view display.
        cv2.imshow('MediaPipe Face Detection', cv2.resize(image, None, fx=1, fy=1))
        if cv2.waitKey(1) == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# label_id: 0
# score: 0.5266126394271851
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7257428169250488
#     ymin: 0.1595146805047989
#     width: 0.3765987157821655
#     height: 0.5020328164100647
#   }
#   relative_keypoints {
#     x: 0.8131420612335205
#     y: 0.29072511196136475
#   }
#   relative_keypoints {
#     x: 0.9431969523429871
#     y: 0.2910804748535156
#   }
#   relative_keypoints {
#     x: 0.8446270227432251
#     y: 0.413544237613678
#   }
#   relative_keypoints {
#     x: 0.8601588606834412
#     y: 0.5241329073905945
#   }
#   relative_keypoints {
#     x: 0.7867377996444702
#     y: 0.34432458877563477
#   }
#   relative_keypoints {
#     x: 1.0732667446136475
#     y: 0.34328848123550415
#   }
# }
#
# label_id: 0
# score: 0.5094602704048157
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7678800821304321
#     ymin: 0.1972685009241104
#     width: 0.34027397632598877
#     height: 0.45369887351989746
#   }
#   relative_keypoints {
#     x: 0.8251392245292664
#     y: 0.3296988010406494
#   }
#   relative_keypoints {
#     x: 0.935274600982666
#     y: 0.32231003046035767
#   }
#   relative_keypoints {
#     x: 0.8337967395782471
#     y: 0.45130276679992676
#   }
#   relative_keypoints {
#     x: 0.85909104347229
#     y: 0.5431866645812988
#   }
#   relative_keypoints {
#     x: 0.8352675437927246
#     y: 0.34656763076782227
#   }
#   relative_keypoints {
#     x: 1.089882731437683
#     y: 0.3350071310997009
#   }
# }
#
# label_id: 0
# score: 0.5157745480537415
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7234897613525391
#     ymin: 0.16613797843456268
#     width: 0.387593150138855
#     height: 0.5166956782341003
#   }
#   relative_keypoints {
#     x: 0.8035159111022949
#     y: 0.31072646379470825
#   }
#   relative_keypoints {
#     x: 0.9267511367797852
#     y: 0.30381977558135986
#   }
#   relative_keypoints {
#     x: 0.8192760348320007
#     y: 0.4343765377998352
#   }
#   relative_keypoints {
#     x: 0.8431398272514343
#     y: 0.5437778830528259
#   }
#   relative_keypoints {
#     x: 0.800747275352478
#     y: 0.36401742696762085
#   }
#   relative_keypoints {
#     x: 1.0852243900299072
#     y: 0.3475995659828186
#   }
# }
#
# label_id: 0
# score: 0.5245025157928467
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7149600982666016
#     ymin: 0.16283877193927765
#     width: 0.3985145092010498
#     height: 0.53126060962677
#   }
#   relative_keypoints {
#     x: 0.7948193550109863
#     y: 0.3172416090965271
#   }
#   relative_keypoints {
#     x: 0.9205538034439087
#     y: 0.3159119486808777
#   }
#   relative_keypoints {
#     x: 0.8039358854293823
#     y: 0.45144182443618774
#   }
#   relative_keypoints {
#     x: 0.8287867903709412
#     y: 0.5578463673591614
#   }
#   relative_keypoints {
#     x: 0.7997497320175171
#     y: 0.3604307770729065
#   }
#   relative_keypoints {
#     x: 1.0849707126617432
#     y: 0.3581508994102478
#   }
# }
#
# label_id: 0
# score: 0.5207305550575256
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7080817222595215
#     ymin: 0.14582844078540802
#     width: 0.4131326675415039
#     height: 0.5507533550262451
#   }
#   relative_keypoints {
#     x: 0.7867926359176636
#     y: 0.3087778687477112
#   }
#   relative_keypoints {
#     x: 0.9203845858573914
#     y: 0.3131825923919678
#   }
#   relative_keypoints {
#     x: 0.7947166562080383
#     y: 0.45530015230178833
#   }
#   relative_keypoints {
#     x: 0.8208433389663696
#     y: 0.5607879161834717
#   }
#   relative_keypoints {
#     x: 0.7935588359832764
#     y: 0.34332531690597534
#   }
#   relative_keypoints {
#     x: 1.0930684804916382
#     y: 0.35109972953796387
#   }
# }
#
# label_id: 0
# score: 0.5106502175331116
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7086057066917419
#     ymin: 0.151975616812706
#     width: 0.41371840238571167
#     height: 0.5515341758728027
#   }
#   relative_keypoints {
#     x: 0.7922079563140869
#     y: 0.3123818039894104
#   }
#   relative_keypoints {
#     x: 0.9272276163101196
#     y: 0.32035237550735474
#   }
#   relative_keypoints {
#     x: 0.7997341156005859
#     y: 0.459084689617157
#   }
#   relative_keypoints {
#     x: 0.8215548992156982
#     y: 0.5659544467926025
#   }
#   relative_keypoints {
#     x: 0.7930198907852173
#     y: 0.34899526834487915
#   }
#   relative_keypoints {
#     x: 1.0958659648895264
#     y: 0.3661734461784363
#   }
# }
#
# label_id: 0
# score: 0.5187163352966309
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6870233416557312
#     ymin: 0.1672789305448532
#     width: 0.4640873074531555
#     height: 0.6186715364456177
#   }
#   relative_keypoints {
#     x: 0.7683261632919312
#     y: 0.33227258920669556
#   }
#   relative_keypoints {
#     x: 0.9215828776359558
#     y: 0.3210359215736389
#   }
#   relative_keypoints {
#     x: 0.7834689617156982
#     y: 0.4705560803413391
#   }
#   relative_keypoints {
#     x: 0.819647490978241
#     y: 0.6081867814064026
#   }
#   relative_keypoints {
#     x: 0.7814797163009644
#     y: 0.4040980339050293
#   }
#   relative_keypoints {
#     x: 1.1124308109283447
#     y: 0.3866010308265686
#   }
# }
#
# label_id: 0
# score: 0.5129830837249756
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6897603273391724
#     ymin: 0.17685534060001373
#     width: 0.45886754989624023
#     height: 0.6117115616798401
#   }
#   relative_keypoints {
#     x: 0.7654141187667847
#     y: 0.33825159072875977
#   }
#   relative_keypoints {
#     x: 0.9149772524833679
#     y: 0.3279758095741272
#   }
#   relative_keypoints {
#     x: 0.7730121612548828
#     y: 0.47365546226501465
#   }
#   relative_keypoints {
#     x: 0.8111096620559692
#     y: 0.6109611988067627
#   }
#   relative_keypoints {
#     x: 0.7871028780937195
#     y: 0.41185659170150757
#   }
#   relative_keypoints {
#     x: 1.1130480766296387
#     y: 0.3968340754508972
#   }
# }
#
# label_id: 0
# score: 0.5210711359977722
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6859567165374756
#     ymin: 0.17885549366474152
#     width: 0.4582151174545288
#     height: 0.6108447313308716
#   }
#   relative_keypoints {
#     x: 0.7603424787521362
#     y: 0.3367807865142822
#   }
#   relative_keypoints {
#     x: 0.9110256433486938
#     y: 0.3372710347175598
#   }
#   relative_keypoints {
#     x: 0.7609918117523193
#     y: 0.47670549154281616
#   }
#   relative_keypoints {
#     x: 0.7959384918212891
#     y: 0.6134135127067566
#   }
#   relative_keypoints {
#     x: 0.7843692302703857
#     y: 0.4056694507598877
#   }
#   relative_keypoints {
#     x: 1.1118190288543701
#     y: 0.41282057762145996
#   }
# }
#
# label_id: 0
# score: 0.523551344871521
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6753655076026917
#     ymin: 0.15920357406139374
#     width: 0.45427805185317993
#     height: 0.605607271194458
#   }
#   relative_keypoints {
#     x: 0.7569413781166077
#     y: 0.3254088759422302
#   }
#   relative_keypoints {
#     x: 0.9085063934326172
#     y: 0.3378540873527527
#   }
#   relative_keypoints {
#     x: 0.7556357383728027
#     y: 0.4748360514640808
#   }
#   relative_keypoints {
#     x: 0.7820675373077393
#     y: 0.5989919304847717
#   }
#   relative_keypoints {
#     x: 0.7684085965156555
#     y: 0.37101250886917114
#   }
#   relative_keypoints {
#     x: 1.1038705110549927
#     y: 0.40296441316604614
#   }
# }
#
# label_id: 0
# score: 0.531999945640564
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6707586050033569
#     ymin: 0.15200860798358917
#     width: 0.45654797554016113
#     height: 0.6086370348930359
#   }
#   relative_keypoints {
#     x: 0.7546979784965515
#     y: 0.3224104046821594
#   }
#   relative_keypoints {
#     x: 0.9077220559120178
#     y: 0.3402605652809143
#   }
#   relative_keypoints {
#     x: 0.7524167895317078
#     y: 0.47948968410491943
#   }
#   relative_keypoints {
#     x: 0.7765591740608215
#     y: 0.6010807156562805
#   }
#   relative_keypoints {
#     x: 0.7653806209564209
#     y: 0.3617163300514221
#   }
#   relative_keypoints {
#     x: 1.101854920387268
#     y: 0.4041145443916321
#   }
# }
#
# label_id: 0
# score: 0.5259964466094971
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6652147769927979
#     ymin: 0.15573270618915558
#     width: 0.4623759984970093
#     height: 0.6163874864578247
#   }
#   relative_keypoints {
#     x: 0.7366644144058228
#     y: 0.3211211562156677
#   }
#   relative_keypoints {
#     x: 0.8864691257476807
#     y: 0.3405752182006836
#   }
#   relative_keypoints {
#     x: 0.7244693636894226
#     y: 0.485063374042511
#   }
#   relative_keypoints {
#     x: 0.7580365538597107
#     y: 0.6127046942710876
#   }
#   relative_keypoints {
#     x: 0.7731861472129822
#     y: 0.367104709148407
#   }
#   relative_keypoints {
#     x: 1.1019245386123657
#     y: 0.405029296875
#   }
# }
#
# label_id: 0
# score: 0.6511463522911072
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6571342945098877
#     ymin: 0.13496102392673492
#     width: 0.4616117477416992
#     height: 0.6153889298439026
#   }
#   relative_keypoints {
#     x: 0.7274417877197266
#     y: 0.30754297971725464
#   }
#   relative_keypoints {
#     x: 0.8769544959068298
#     y: 0.32349908351898193
#   }
#   relative_keypoints {
#     x: 0.7166159749031067
#     y: 0.47136181592941284
#   }
#   relative_keypoints {
#     x: 0.7508485913276672
#     y: 0.5954073071479797
#   }
#   relative_keypoints {
#     x: 0.7636640071868896
#     y: 0.35002708435058594
#   }
#   relative_keypoints {
#     x: 1.095673680305481
#     y: 0.37814027070999146
#   }
# }
#
# label_id: 0
# score: 0.7494531869888306
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6493996977806091
#     ymin: 0.132801815867424
#     width: 0.468391478061676
#     height: 0.6244253516197205
#   }
#   relative_keypoints {
#     x: 0.7207804918289185
#     y: 0.3020547032356262
#   }
#   relative_keypoints {
#     x: 0.8668778538703918
#     y: 0.3228369951248169
#   }
#   relative_keypoints {
#     x: 0.701715886592865
#     y: 0.4659426808357239
#   }
#   relative_keypoints {
#     x: 0.7361475825309753
#     y: 0.5940223336219788
#   }
#   relative_keypoints {
#     x: 0.7623108625411987
#     y: 0.3479616641998291
#   }
#   relative_keypoints {
#     x: 1.0949208736419678
#     y: 0.38734114170074463
#   }
# }
#
# label_id: 0
# score: 0.8057768940925598
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6348952054977417
#     ymin: 0.12288109958171844
#     width: 0.4753016233444214
#     height: 0.6336312890052795
#   }
#   relative_keypoints {
#     x: 0.7054987549781799
#     y: 0.30164647102355957
#   }
#   relative_keypoints {
#     x: 0.8548197746276855
#     y: 0.31606948375701904
#   }
#   relative_keypoints {
#     x: 0.6896981000900269
#     y: 0.4667285084724426
#   }
#   relative_keypoints {
#     x: 0.7249886989593506
#     y: 0.5935061573982239
#   }
#   relative_keypoints {
#     x: 0.746839165687561
#     y: 0.3463268280029297
#   }
#   relative_keypoints {
#     x: 1.0865670442581177
#     y: 0.37510186433792114
#   }
# }
#
# label_id: 0
# score: 0.7930972576141357
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6162627339363098
#     ymin: 0.10671480000019073
#     width: 0.48773306608200073
#     height: 0.650204598903656
#   }
#   relative_keypoints {
#     x: 0.6839426755905151
#     y: 0.30763256549835205
#   }
#   relative_keypoints {
#     x: 0.832617461681366
#     y: 0.30287301540374756
#   }
#   relative_keypoints {
#     x: 0.6731200218200684
#     y: 0.47439688444137573
#   }
#   relative_keypoints {
#     x: 0.7185577154159546
#     y: 0.5984208583831787
#   }
#   relative_keypoints {
#     x: 0.7350380420684814
#     y: 0.35133206844329834
#   }
#   relative_keypoints {
#     x: 1.075275182723999
#     y: 0.3386971950531006
#   }
# }
# label_id: 0
# score: 0.778772234916687
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5958513021469116
#     ymin: 0.07784776389598846
#     width: 0.5119822025299072
#     height: 0.6825332641601562
#   }
#   relative_keypoints {
#     x: 0.6633085608482361
#     y: 0.3005397915840149
#   }
#   relative_keypoints {
#     x: 0.8211962580680847
#     y: 0.29271048307418823
#   }
#   relative_keypoints {
#     x: 0.6538650989532471
#     y: 0.4826924204826355
#   }
#   relative_keypoints {
#     x: 0.7054544687271118
#     y: 0.6049646735191345
#   }
#   relative_keypoints {
#     x: 0.719914972782135
#     y: 0.33519643545150757
#   }
#   relative_keypoints {
#     x: 1.077089786529541
#     y: 0.31264573335647583
#   }
# }
#
# label_id: 0
# score: 0.8106164932250977
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5873649716377258
#     ymin: 0.07454949617385864
#     width: 0.5203446745872498
#     height: 0.6936814188957214
#   }
#   relative_keypoints {
#     x: 0.6562405228614807
#     y: 0.2995907664299011
#   }
#   relative_keypoints {
#     x: 0.8138962984085083
#     y: 0.2880170941352844
#   }
#   relative_keypoints {
#     x: 0.6445528268814087
#     y: 0.48075729608535767
#   }
#   relative_keypoints {
#     x: 0.6980814337730408
#     y: 0.6065033078193665
#   }
#   relative_keypoints {
#     x: 0.7160726189613342
#     y: 0.3378368020057678
#   }
#   relative_keypoints {
#     x: 1.0751484632492065
#     y: 0.31162089109420776
#   }
# }
#
# label_id: 0
# score: 0.802365243434906
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.579210638999939
#     ymin: 0.07117463648319244
#     width: 0.5218349695205688
#     height: 0.6956703066825867
#   }
#   relative_keypoints {
#     x: 0.6480305790901184
#     y: 0.3022925853729248
#   }
#   relative_keypoints {
#     x: 0.7986164689064026
#     y: 0.2775360941886902
#   }
#   relative_keypoints {
#     x: 0.6359171867370605
#     y: 0.4768884778022766
#   }
#   relative_keypoints {
#     x: 0.6956802010536194
#     y: 0.6035779118537903
#   }
#   relative_keypoints {
#     x: 0.7183047533035278
#     y: 0.34637582302093506
#   }
#   relative_keypoints {
#     x: 1.0667113065719604
#     y: 0.29371321201324463
#   }
# }
#
# label_id: 0
# score: 0.8212325572967529
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5782663822174072
#     ymin: 0.07419084012508392
#     width: 0.520779013633728
#     height: 0.6942639350891113
#   }
#   relative_keypoints {
#     x: 0.6487433314323425
#     y: 0.3010839819908142
#   }
#   relative_keypoints {
#     x: 0.801516592502594
#     y: 0.28709787130355835
#   }
#   relative_keypoints {
#     x: 0.6365700364112854
#     y: 0.48203498125076294
#   }
#   relative_keypoints {
#     x: 0.6926590204238892
#     y: 0.6079208254814148
#   }
#   relative_keypoints {
#     x: 0.717348575592041
#     y: 0.3410518765449524
#   }
#   relative_keypoints {
#     x: 1.0648202896118164
#     y: 0.3068076968193054
#   }
# }
#
# label_id: 0
# score: 0.839007556438446
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5761289596557617
#     ymin: 0.07981212437152863
#     width: 0.5245298147201538
#     height: 0.6992784738540649
#   }
#   relative_keypoints {
#     x: 0.649481475353241
#     y: 0.3054061532020569
#   }
#   relative_keypoints {
#     x: 0.798713207244873
#     y: 0.29537737369537354
#   }
#   relative_keypoints {
#     x: 0.6332604885101318
#     y: 0.4907853603363037
#   }
#   relative_keypoints {
#     x: 0.6890691518783569
#     y: 0.6171790957450867
#   }
#   relative_keypoints {
#     x: 0.7206185460090637
#     y: 0.3441382050514221
#   }
#   relative_keypoints {
#     x: 1.0633078813552856
#     y: 0.31594032049179077
#   }
# }
#
# label_id: 0
# score: 0.8617630004882812
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5814908146858215
#     ymin: 0.10528866946697235
#     width: 0.5259024500846863
#     height: 0.7011082172393799
#   }
#   relative_keypoints {
#     x: 0.6503013968467712
#     y: 0.3323518633842468
#   }
#   relative_keypoints {
#     x: 0.7939733862876892
#     y: 0.3105396628379822
#   }
#   relative_keypoints {
#     x: 0.6269463300704956
#     y: 0.5066893100738525
#   }
#   relative_keypoints {
#     x: 0.6885426044464111
#     y: 0.6386809945106506
#   }
#   relative_keypoints {
#     x: 0.734269917011261
#     y: 0.3757476210594177
#   }
#   relative_keypoints {
#     x: 1.0725256204605103
#     y: 0.33271437883377075
#   }
# }
#
# label_id: 0
# score: 0.8612596392631531
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5881879925727844
#     ymin: 0.1314731389284134
#     width: 0.5209458470344543
#     height: 0.6944998502731323
#   }
#   relative_keypoints {
#     x: 0.6571913361549377
#     y: 0.3531137704849243
#   }
#   relative_keypoints {
#     x: 0.798291027545929
#     y: 0.33687835931777954
#   }
#   relative_keypoints {
#     x: 0.6325735449790955
#     y: 0.5293305516242981
#   }
#   relative_keypoints {
#     x: 0.6926165223121643
#     y: 0.6599006652832031
#   }
#   relative_keypoints {
#     x: 0.7400572299957275
#     y: 0.3973998427391052
#   }
#   relative_keypoints {
#     x: 1.0735081434249878
#     y: 0.3613906502723694
#   }
# }
#
# label_id: 0
# score: 0.8174154758453369
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5979301333427429
#     ymin: 0.15826310217380524
#     width: 0.5095450282096863
#     height: 0.6792928576469421
#   }
#   relative_keypoints {
#     x: 0.6645644307136536
#     y: 0.36911100149154663
#   }
#   relative_keypoints {
#     x: 0.8119645714759827
#     y: 0.37775737047195435
#   }
#   relative_keypoints {
#     x: 0.6391895413398743
#     y: 0.5578504204750061
#   }
#   relative_keypoints {
#     x: 0.6906982660293579
#     y: 0.6809473037719727
#   }
#   relative_keypoints {
#     x: 0.7355350255966187
#     y: 0.3976936340332031
#   }
#   relative_keypoints {
#     x: 1.0795435905456543
#     y: 0.4030234217643738
#   }
# }
#
# label_id: 0
# score: 0.7822747826576233
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6058422327041626
#     ymin: 0.17217175662517548
#     width: 0.4987999200820923
#     height: 0.6649640798568726
#   }
#   relative_keypoints {
#     x: 0.6709855198860168
#     y: 0.3755232095718384
#   }
#   relative_keypoints {
#     x: 0.8280885815620422
#     y: 0.39215439558029175
#   }
#   relative_keypoints {
#     x: 0.6537049412727356
#     y: 0.5648608803749084
#   }
#   relative_keypoints {
#     x: 0.6974961161613464
#     y: 0.6834008693695068
#   }
#   relative_keypoints {
#     x: 0.7232741713523865
#     y: 0.4021110534667969
#   }
#   relative_keypoints {
#     x: 1.0792124271392822
#     y: 0.42437320947647095
#   }
# }
#
# label_id: 0
# score: 0.7505747675895691
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6263934373855591
#     ymin: 0.19128255546092987
#     width: 0.4828922748565674
#     height: 0.6437556743621826
#   }
#   relative_keypoints {
#     x: 0.6916497945785522
#     y: 0.39088475704193115
#   }
#   relative_keypoints {
#     x: 0.8523451685905457
#     y: 0.40778398513793945
#   }
#   relative_keypoints {
#     x: 0.6859856247901917
#     y: 0.575573742389679
#   }
#   relative_keypoints {
#     x: 0.7259029150009155
#     y: 0.6878664493560791
#   }
#   relative_keypoints {
#     x: 0.7296847701072693
#     y: 0.4132691025733948
#   }
#   relative_keypoints {
#     x: 1.085802674293518
#     y: 0.43371206521987915
#   }
# }
#
# label_id: 0
# score: 0.7573423385620117
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6411968469619751
#     ymin: 0.21215204894542694
#     width: 0.46429693698883057
#     height: 0.6189667582511902
#   }
#   relative_keypoints {
#     x: 0.7047485709190369
#     y: 0.40361422300338745
#   }
#   relative_keypoints {
#     x: 0.8511314392089844
#     y: 0.4129696488380432
#   }
#   relative_keypoints {
#     x: 0.6944746375083923
#     y: 0.5744150280952454
#   }
#   relative_keypoints {
#     x: 0.7363117337226868
#     y: 0.6853907108306885
#   }
#   relative_keypoints {
#     x: 0.7479643225669861
#     y: 0.428549587726593
#   }
#   relative_keypoints {
#     x: 1.0818815231323242
#     y: 0.4365580677986145
#   }
# }
#
# label_id: 0
# score: 0.7123488783836365
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6558973789215088
#     ymin: 0.20891477167606354
#     width: 0.455269455909729
#     height: 0.6069303154945374
#   }
#   relative_keypoints {
#     x: 0.7202810645103455
#     y: 0.40021711587905884
#   }
#   relative_keypoints {
#     x: 0.8708411455154419
#     y: 0.4110569357872009
#   }
#   relative_keypoints {
#     x: 0.7158186435699463
#     y: 0.5719513893127441
#   }
#   relative_keypoints {
#     x: 0.7539641261100769
#     y: 0.6779184341430664
#   }
#   relative_keypoints {
#     x: 0.753884494304657
#     y: 0.4178953170776367
#   }
#   relative_keypoints {
#     x: 1.0877668857574463
#     y: 0.43229764699935913
#   }
# }
#
# label_id: 0
# score: 0.717271625995636
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6617220044136047
#     ymin: 0.2188260704278946
#     width: 0.44836002588272095
#     height: 0.5977221131324768
#   }
#   relative_keypoints {
#     x: 0.7266070246696472
#     y: 0.40835660696029663
#   }
#   relative_keypoints {
#     x: 0.8787783980369568
#     y: 0.4200291037559509
#   }
#   relative_keypoints {
#     x: 0.7301075458526611
#     y: 0.5822482705116272
#   }
#   relative_keypoints {
#     x: 0.76725834608078
#     y: 0.6840561032295227
#   }
#   relative_keypoints {
#     x: 0.7535894513130188
#     y: 0.42353713512420654
#   }
#   relative_keypoints {
#     x: 1.0857317447662354
#     y: 0.4341534376144409
#   }
# }
#
# label_id: 0
# score: 0.6839194297790527
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6719295382499695
#     ymin: 0.2238679677248001
#     width: 0.43992096185684204
#     height: 0.5864729285240173
#   }
#   relative_keypoints {
#     x: 0.7392140626907349
#     y: 0.4023759961128235
#   }
#   relative_keypoints {
#     x: 0.886998176574707
#     y: 0.42800986766815186
#   }
#   relative_keypoints {
#     x: 0.7348468899726868
#     y: 0.5778734087944031
#   }
#   relative_keypoints {
#     x: 0.7654197812080383
#     y: 0.6781619191169739
#   }
#   relative_keypoints {
#     x: 0.7620494365692139
#     y: 0.410672128200531
#   }
#   relative_keypoints {
#     x: 1.089673399925232
#     y: 0.4526594281196594
#   }
# }
# label_id: 0
# score: 0.7166774868965149
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6752303242683411
#     ymin: 0.22960548102855682
#     width: 0.4330812096595764
#     height: 0.5773589015007019
#   }
#   relative_keypoints {
#     x: 0.7458977103233337
#     y: 0.3992825746536255
#   }
#   relative_keypoints {
#     x: 0.8962010741233826
#     y: 0.431851863861084
#   }
#   relative_keypoints {
#     x: 0.7437077760696411
#     y: 0.570458710193634
#   }
#   relative_keypoints {
#     x: 0.7678893804550171
#     y: 0.6704809069633484
#   }
#   relative_keypoints {
#     x: 0.7562037110328674
#     y: 0.4102514386177063
#   }
#   relative_keypoints {
#     x: 1.0885064601898193
#     y: 0.4689751863479614
#   }
# }
#
# label_id: 0
# score: 0.6902979612350464
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6804047226905823
#     ymin: 0.22505666315555573
#     width: 0.4286455512046814
#     height: 0.5714442729949951
#   }
#   relative_keypoints {
#     x: 0.7533116936683655
#     y: 0.38557541370391846
#   }
#   relative_keypoints {
#     x: 0.9045412540435791
#     y: 0.42111146450042725
#   }
#   relative_keypoints {
#     x: 0.7492534518241882
#     y: 0.5494909286499023
#   }
#   relative_keypoints {
#     x: 0.769027590751648
#     y: 0.6547873020172119
#   }
#   relative_keypoints {
#     x: 0.7595636248588562
#     y: 0.4048316478729248
#   }
#   relative_keypoints {
#     x: 1.0911521911621094
#     y: 0.4763304591178894
#   }
# }
#
# label_id: 0
# score: 0.6173230409622192
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7056090831756592
#     ymin: 0.2435956448316574
#     width: 0.41732752323150635
#     height: 0.5563480854034424
#   }
#   relative_keypoints {
#     x: 0.7803844809532166
#     y: 0.41054707765579224
#   }
#   relative_keypoints {
#     x: 0.9203767776489258
#     y: 0.4216081500053406
#   }
#   relative_keypoints {
#     x: 0.7878426909446716
#     y: 0.5643298625946045
#   }
#   relative_keypoints {
#     x: 0.8148593306541443
#     y: 0.6656530499458313
#   }
#   relative_keypoints {
#     x: 0.7871645092964172
#     y: 0.4368569254875183
#   }
#   relative_keypoints {
#     x: 1.0956825017929077
#     y: 0.45343899726867676
#   }
# }
#
# label_id: 0
# score: 0.6173230409622192
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7056090831756592
#     ymin: 0.2435956448316574
#     width: 0.41732752323150635
#     height: 0.5563480854034424
#   }
#   relative_keypoints {
#     x: 0.7803844809532166
#     y: 0.41054707765579224
#   }
#   relative_keypoints {
#     x: 0.9203767776489258
#     y: 0.4216081500053406
#   }
#   relative_keypoints {
#     x: 0.7878426909446716
#     y: 0.5643298625946045
#   }
#   relative_keypoints {
#     x: 0.8148593306541443
#     y: 0.6656530499458313
#   }
#   relative_keypoints {
#     x: 0.7871645092964172
#     y: 0.4368569254875183
#   }
#   relative_keypoints {
#     x: 1.0956825017929077
#     y: 0.45343899726867676
#   }
# }
#
# label_id: 0
# score: 0.6393045783042908
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7200354933738708
#     ymin: 0.2478954941034317
#     width: 0.3978641629219055
#     height: 0.5303971767425537
#   }
#   relative_keypoints {
#     x: 0.7875781059265137
#     y: 0.40333670377731323
#   }
#   relative_keypoints {
#     x: 0.9268160462379456
#     y: 0.4277809262275696
#   }
#   relative_keypoints {
#     x: 0.7907315492630005
#     y: 0.5604884624481201
#   }
#   relative_keypoints {
#     x: 0.8135425448417664
#     y: 0.655451774597168
#   }
#   relative_keypoints {
#     x: 0.7944933772087097
#     y: 0.41765081882476807
#   }
#   relative_keypoints {
#     x: 1.0974200963974
#     y: 0.4609333872795105
#   }
# }
#
# label_id: 0
# score: 0.6417670249938965
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7296379804611206
#     ymin: 0.26183491945266724
#     width: 0.387800931930542
#     height: 0.5169782638549805
#   }
#   relative_keypoints {
#     x: 0.8022231459617615
#     y: 0.4056444764137268
#   }
#   relative_keypoints {
#     x: 0.9389905333518982
#     y: 0.4355429410934448
#   }
#   relative_keypoints {
#     x: 0.8064360022544861
#     y: 0.5581944584846497
#   }
#   relative_keypoints {
#     x: 0.8230952620506287
#     y: 0.6542369723320007
#   }
#   relative_keypoints {
#     x: 0.8004834055900574
#     y: 0.42346668243408203
#   }
#   relative_keypoints {
#     x: 1.0964444875717163
#     y: 0.481315553188324
#   }
# }
#
# label_id: 0
# score: 0.677643358707428
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7386023998260498
#     ymin: 0.2597191333770752
#     width: 0.36855411529541016
#     height: 0.49136513471603394
#   }
#   relative_keypoints {
#     x: 0.8116181492805481
#     y: 0.38848626613616943
#   }
#   relative_keypoints {
#     x: 0.9517045021057129
#     y: 0.4363066554069519
#   }
#   relative_keypoints {
#     x: 0.8190436363220215
#     y: 0.545952558517456
#   }
#   relative_keypoints {
#     x: 0.822644054889679
#     y: 0.6376405358314514
#   }
#   relative_keypoints {
#     x: 0.7932531833648682
#     y: 0.38654619455337524
#   }
#   relative_keypoints {
#     x: 1.093355417251587
#     y: 0.48053210973739624
#   }
# }
#
# label_id: 0
# score: 0.6301663517951965
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7441056966781616
#     ymin: 0.26522761583328247
#     width: 0.3578472137451172
#     height: 0.47708505392074585
#   }
#   relative_keypoints {
#     x: 0.8218361139297485
#     y: 0.3933814764022827
#   }
#   relative_keypoints {
#     x: 0.9595395922660828
#     y: 0.4395705461502075
#   }
#   relative_keypoints {
#     x: 0.838711678981781
#     y: 0.5482425689697266
#   }
#   relative_keypoints {
#     x: 0.8396537899971008
#     y: 0.6350573897361755
#   }
#   relative_keypoints {
#     x: 0.7917195558547974
#     y: 0.38989317417144775
#   }
#   relative_keypoints {
#     x: 1.0859568119049072
#     y: 0.4797114133834839
#   }
# }
#
# label_id: 0
# score: 0.5455994606018066
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.730529248714447
#     ymin: 0.2602945566177368
#     width: 0.38269585371017456
#     height: 0.5101689696311951
#   }
#   relative_keypoints {
#     x: 0.8216488361358643
#     y: 0.4084523320198059
#   }
#   relative_keypoints {
#     x: 0.9613709449768066
#     y: 0.4329988956451416
#   }
#   relative_keypoints {
#     x: 0.8482365012168884
#     y: 0.5583552718162537
#   }
#   relative_keypoints {
#     x: 0.8554019927978516
#     y: 0.6510984897613525
#   }
#   relative_keypoints {
#     x: 0.7881442308425903
#     y: 0.42303627729415894
#   }
#   relative_keypoints {
#     x: 1.0868555307388306
#     y: 0.47062188386917114
#   }
# }
#
# label_id: 0
# score: 0.530728816986084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7357997298240662
#     ymin: 0.2343520075082779
#     width: 0.3190104365348816
#     height: 0.4253462553024292
#   }
#   relative_keypoints {
#     x: 0.7758397459983826
#     y: 0.36518627405166626
#   }
#   relative_keypoints {
#     x: 0.8957082629203796
#     y: 0.380280077457428
#   }
#   relative_keypoints {
#     x: 0.7922760248184204
#     y: 0.48147135972976685
#   }
#   relative_keypoints {
#     x: 0.8162886500358582
#     y: 0.5622538924217224
#   }
#   relative_keypoints {
#     x: 0.7822416424751282
#     y: 0.38476699590682983
#   }
#   relative_keypoints {
#     x: 1.055371880531311
#     y: 0.39721250534057617
#   }
# }
#
# label_id: 0
# score: 0.5237320065498352
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7249590158462524
#     ymin: 0.2662748694419861
#     width: 0.3169354200363159
#     height: 0.4225795269012451
#   }
#   relative_keypoints {
#     x: 0.7632541656494141
#     y: 0.3920193314552307
#   }
#   relative_keypoints {
#     x: 0.8832675218582153
#     y: 0.40590816736221313
#   }
#   relative_keypoints {
#     x: 0.7769404649734497
#     y: 0.5065112709999084
#   }
#   relative_keypoints {
#     x: 0.7985236644744873
#     y: 0.5897560119628906
#   }
#   relative_keypoints {
#     x: 0.7693285346031189
#     y: 0.4124677777290344
#   }
#   relative_keypoints {
#     x: 1.048413872718811
#     y: 0.4304302930831909
#   }
# }
#
# label_id: 0
# score: 0.5817919373512268
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6636685729026794
#     ymin: 0.28955912590026855
#     width: 0.4358435273170471
#     height: 0.5810478329658508
#   }
#   relative_keypoints {
#     x: 0.7421457171440125
#     y: 0.42750364542007446
#   }
#   relative_keypoints {
#     x: 0.8865981698036194
#     y: 0.4775598645210266
#   }
#   relative_keypoints {
#     x: 0.7196282148361206
#     y: 0.5874397158622742
#   }
#   relative_keypoints {
#     x: 0.7343695163726807
#     y: 0.7130703926086426
#   }
#   relative_keypoints {
#     x: 0.7555792927742004
#     y: 0.4570156931877136
#   }
#   relative_keypoints {
#     x: 1.0835131406784058
#     y: 0.5665590763092041
#   }
# }
#
# label_id: 0
# score: 0.5765022039413452
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6838325262069702
#     ymin: 0.3221040368080139
#     width: 0.3868081569671631
#     height: 0.5156928300857544
#   }
#   relative_keypoints {
#     x: 0.7690010070800781
#     y: 0.4420909285545349
#   }
#   relative_keypoints {
#     x: 0.9069995284080505
#     y: 0.5003870129585266
#   }
#   relative_keypoints {
#     x: 0.7675435543060303
#     y: 0.5907863974571228
#   }
#   relative_keypoints {
#     x: 0.7675006985664368
#     y: 0.6999337673187256
#   }
#   relative_keypoints {
#     x: 0.7495138645172119
#     y: 0.45860159397125244
#   }
#   relative_keypoints {
#     x: 1.0601733922958374
#     y: 0.5819215178489685
#   }
# }
#
# label_id: 0
# score: 0.5561421513557434
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6728821396827698
#     ymin: 0.3478958010673523
#     width: 0.3705483078956604
#     height: 0.4940224885940552
#   }
#   relative_keypoints {
#     x: 0.7688333988189697
#     y: 0.46534091234207153
#   }
#   relative_keypoints {
#     x: 0.9071438908576965
#     y: 0.543349027633667
#   }
#   relative_keypoints {
#     x: 0.7724527716636658
#     y: 0.6247849464416504
#   }
#   relative_keypoints {
#     x: 0.7590339779853821
#     y: 0.7216915488243103
#   }
#   relative_keypoints {
#     x: 0.7287916541099548
#     y: 0.45393091440200806
#   }
#   relative_keypoints {
#     x: 1.0323807001113892
#     y: 0.6154173016548157
#   }
# }
# label_id: 0
# score: 0.5678991675376892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6676987409591675
#     ymin: 0.3596712350845337
#     width: 0.38739681243896484
#     height: 0.5164825320243835
#   }
#   relative_keypoints {
#     x: 0.7628656029701233
#     y: 0.48308223485946655
#   }
#   relative_keypoints {
#     x: 0.9124889969825745
#     y: 0.5518714785575867
#   }
#   relative_keypoints {
#     x: 0.7773817777633667
#     y: 0.6426363587379456
#   }
#   relative_keypoints {
#     x: 0.7682069540023804
#     y: 0.7463216185569763
#   }
#   relative_keypoints {
#     x: 0.7195701003074646
#     y: 0.4848114848136902
#   }
#   relative_keypoints {
#     x: 1.0439835786819458
#     y: 0.6236584186553955
#   }
# }
#
# label_id: 0
# score: 0.5217325091362
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6936206221580505
#     ymin: 0.3518074154853821
#     width: 0.3532528281211853
#     height: 0.4709674119949341
#   }
#   relative_keypoints {
#     x: 0.7799251675605774
#     y: 0.48148781061172485
#   }
#   relative_keypoints {
#     x: 0.919723629951477
#     y: 0.5466777682304382
#   }
#   relative_keypoints {
#     x: 0.7973838448524475
#     y: 0.633014976978302
#   }
#   relative_keypoints {
#     x: 0.7893813252449036
#     y: 0.7168557643890381
#   }
#   relative_keypoints {
#     x: 0.7365163564682007
#     y: 0.45948803424835205
#   }
#   relative_keypoints {
#     x: 1.0412688255310059
#     y: 0.5871128439903259
#   }
# }
#
# label_id: 0
# score: 0.5241047143936157
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6805739998817444
#     ymin: 0.3380783796310425
#     width: 0.39781874418258667
#     height: 0.530343234539032
#   }
#   relative_keypoints {
#     x: 0.7738109827041626
#     y: 0.4861130118370056
#   }
#   relative_keypoints {
#     x: 0.943002462387085
#     y: 0.5398511290550232
#   }
#   relative_keypoints {
#     x: 0.8114556074142456
#     y: 0.6516007781028748
#   }
#   relative_keypoints {
#     x: 0.8075456619262695
#     y: 0.7480810284614563
#   }
#   relative_keypoints {
#     x: 0.7115780711174011
#     y: 0.46956372261047363
#   }
#   relative_keypoints {
#     x: 1.06880521774292
#     y: 0.5791063904762268
#   }
# }
#
# label_id: 0
# score: 0.547330379486084
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6848044395446777
#     ymin: 0.353298544883728
#     width: 0.4201561212539673
#     height: 0.560140073299408
#   }
#   relative_keypoints {
#     x: 0.8261024355888367
#     y: 0.5592784881591797
#   }
#   relative_keypoints {
#     x: 1.0015074014663696
#     y: 0.5957281589508057
#   }
#   relative_keypoints {
#     x: 0.9028357863426208
#     y: 0.7423784732818604
#   }
#   relative_keypoints {
#     x: 0.8853623270988464
#     y: 0.8157290816307068
#   }
#   relative_keypoints {
#     x: 0.7119030356407166
#     y: 0.5009357929229736
#   }
#   relative_keypoints {
#     x: 1.0709642171859741
#     y: 0.5792396068572998
#   }
# }
#
# label_id: 0
# score: 0.5530365109443665
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6870824098587036
#     ymin: 0.34921592473983765
#     width: 0.3945058584213257
#     height: 0.5259240865707397
#   }
#   relative_keypoints {
#     x: 0.7890543937683105
#     y: 0.5124257206916809
#   }
#   relative_keypoints {
#     x: 0.957575261592865
#     y: 0.562225878238678
#   }
#   relative_keypoints {
#     x: 0.8352039456367493
#     y: 0.6840459704399109
#   }
#   relative_keypoints {
#     x: 0.8280541896820068
#     y: 0.7676644325256348
#   }
#   relative_keypoints {
#     x: 0.716693103313446
#     y: 0.47854334115982056
#   }
#   relative_keypoints {
#     x: 1.0652904510498047
#     y: 0.5819902420043945
#   }
# }
#
# label_id: 0
# score: 0.5163389444351196
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7014975547790527
#     ymin: 0.348239004611969
#     width: 0.402174711227417
#     height: 0.5361588001251221
#   }
#   relative_keypoints {
#     x: 0.8360331654548645
#     y: 0.5517392158508301
#   }
#   relative_keypoints {
#     x: 1.004820466041565
#     y: 0.5842697024345398
#   }
#   relative_keypoints {
#     x: 0.9032135009765625
#     y: 0.7165848612785339
#   }
#   relative_keypoints {
#     x: 0.8856191635131836
#     y: 0.7893233895301819
#   }
#   relative_keypoints {
#     x: 0.7281410694122314
#     y: 0.4841569662094116
#   }
#   relative_keypoints {
#     x: 1.0711441040039062
#     y: 0.5667043328285217
#   }
# }
#
# label_id: 0
# score: 0.5427427887916565
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7328504920005798
#     ymin: 0.319685697555542
#     width: 0.23604440689086914
#     height: 0.3147210478782654
#   }
#   relative_keypoints {
#     x: 0.7805987596511841
#     y: 0.44813841581344604
#   }
#   relative_keypoints {
#     x: 0.8651917576789856
#     y: 0.45640140771865845
#   }
#   relative_keypoints {
#     x: 0.7993156313896179
#     y: 0.5479028820991516
#   }
#   relative_keypoints {
#     x: 0.807987630367279
#     y: 0.5856382250785828
#   }
#   relative_keypoints {
#     x: 0.758703887462616
#     y: 0.4038739800453186
#   }
#   relative_keypoints {
#     x: 0.9601212739944458
#     y: 0.41895246505737305
#   }
# }
#
# label_id: 0
# score: 0.5387052893638611
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7313417792320251
#     ymin: 0.3264407515525818
#     width: 0.24050647020339966
#     height: 0.3206709027290344
#   }
#   relative_keypoints {
#     x: 0.7821350693702698
#     y: 0.4605181813240051
#   }
#   relative_keypoints {
#     x: 0.8689030408859253
#     y: 0.46781468391418457
#   }
#   relative_keypoints {
#     x: 0.8047299385070801
#     y: 0.5614290833473206
#   }
#   relative_keypoints {
#     x: 0.8150368332862854
#     y: 0.5979876518249512
#   }
#   relative_keypoints {
#     x: 0.7585460543632507
#     y: 0.4196011424064636
#   }
#   relative_keypoints {
#     x: 0.9617471694946289
#     y: 0.42960304021835327
#   }
# }
#
# label_id: 0
# score: 0.5108819603919983
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6897754669189453
#     ymin: 0.3134658932685852
#     width: 0.4045450687408447
#     height: 0.5393133163452148
#   }
#   relative_keypoints {
#     x: 0.7706843018531799
#     y: 0.46514397859573364
#   }
#   relative_keypoints {
#     x: 0.9206385016441345
#     y: 0.4893952012062073
#   }
#   relative_keypoints {
#     x: 0.7896459698677063
#     y: 0.6152399182319641
#   }
#   relative_keypoints {
#     x: 0.8040292859077454
#     y: 0.723175048828125
#   }
#   relative_keypoints {
#     x: 0.7545230388641357
#     y: 0.48723161220550537
#   }
#   relative_keypoints {
#     x: 1.075933575630188
#     y: 0.5362086296081543
#   }
# }
#
# label_id: 0
# score: 0.5229803919792175
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7145350575447083
#     ymin: 0.3157276511192322
#     width: 0.3647567629814148
#     height: 0.4862592816352844
#   }
#   relative_keypoints {
#     x: 0.8409982323646545
#     y: 0.4602603316307068
#   }
#   relative_keypoints {
#     x: 0.9736009836196899
#     y: 0.5328757166862488
#   }
#   relative_keypoints {
#     x: 0.8672148585319519
#     y: 0.6326671242713928
#   }
#   relative_keypoints {
#     x: 0.846552312374115
#     y: 0.7012856602668762
#   }
#   relative_keypoints {
#     x: 0.7621974349021912
#     y: 0.39649033546447754
#   }
#   relative_keypoints {
#     x: 1.0494588613510132
#     y: 0.5468270182609558
#   }
# }
#
# label_id: 0
# score: 0.5198701024055481
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7155755162239075
#     ymin: 0.32230639457702637
#     width: 0.3371524214744568
#     height: 0.44949203729629517
#   }
#   relative_keypoints {
#     x: 0.8237568140029907
#     y: 0.4403645992279053
#   }
#   relative_keypoints {
#     x: 0.9526071548461914
#     y: 0.501197338104248
#   }
#   relative_keypoints {
#     x: 0.8557537198066711
#     y: 0.5938605666160583
#   }
#   relative_keypoints {
#     x: 0.8395187258720398
#     y: 0.6731617450714111
#   }
#   relative_keypoints {
#     x: 0.7524474263191223
#     y: 0.4152340888977051
#   }
#   relative_keypoints {
#     x: 1.0265491008758545
#     y: 0.5365666747093201
#   }
# }
#
# label_id: 0
# score: 0.5165258049964905
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.708348274230957
#     ymin: 0.29663556814193726
#     width: 0.34196698665618896
#     height: 0.4559152126312256
#   }
#   relative_keypoints {
#     x: 0.7926948070526123
#     y: 0.432809054851532
#   }
#   relative_keypoints {
#     x: 0.9138690233230591
#     y: 0.46944642066955566
#   }
#   relative_keypoints {
#     x: 0.8092943429946899
#     y: 0.5721045136451721
#   }
#   relative_keypoints {
#     x: 0.8114749789237976
#     y: 0.6506423354148865
#   }
#   relative_keypoints {
#     x: 0.7620744705200195
#     y: 0.41771262884140015
#   }
#   relative_keypoints {
#     x: 1.0315886735916138
#     y: 0.49243783950805664
#   }
# }
#
# label_id: 0
# score: 0.5345434546470642
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.701051652431488
#     ymin: 0.26263684034347534
#     width: 0.35691744089126587
#     height: 0.4758496880531311
#   }
#   relative_keypoints {
#     x: 0.7611711621284485
#     y: 0.40526843070983887
#   }
#   relative_keypoints {
#     x: 0.8926810622215271
#     y: 0.43381279706954956
#   }
#   relative_keypoints {
#     x: 0.7728860974311829
#     y: 0.5451231598854065
#   }
#   relative_keypoints {
#     x: 0.788905918598175
#     y: 0.6313827633857727
#   }
#   relative_keypoints {
#     x: 0.7569200992584229
#     y: 0.4061369299888611
#   }
#   relative_keypoints {
#     x: 1.0487029552459717
#     y: 0.4561615586280823
#   }
# }
#
# label_id: 0
# score: 0.5032404661178589
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6856505870819092
#     ymin: 0.26920294761657715
#     width: 0.38497138023376465
#     height: 0.5132585167884827
#   }
#   relative_keypoints {
#     x: 0.7522434592247009
#     y: 0.41188549995422363
#   }
#   relative_keypoints {
#     x: 0.8905815482139587
#     y: 0.448245644569397
#   }
#   relative_keypoints {
#     x: 0.7540543079376221
#     y: 0.5604435801506042
#   }
#   relative_keypoints {
#     x: 0.7681697607040405
#     y: 0.6592469215393066
#   }
#   relative_keypoints {
#     x: 0.7520439624786377
#     y: 0.4208466410636902
#   }
#   relative_keypoints {
#     x: 1.0584022998809814
#     y: 0.4917426109313965
#   }
# }
#
# label_id: 0
# score: 0.5608509182929993
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6836310625076294
#     ymin: 0.26729267835617065
#     width: 0.4184281826019287
#     height: 0.5578234195709229
#   }
#   relative_keypoints {
#     x: 0.7631554007530212
#     y: 0.4200713038444519
#   }
#   relative_keypoints {
#     x: 0.9142197370529175
#     y: 0.453480064868927
#   }
#   relative_keypoints {
#     x: 0.7718051075935364
#     y: 0.5821308493614197
#   }
#   relative_keypoints {
#     x: 0.7874842882156372
#     y: 0.6892595291137695
#   }
#   relative_keypoints {
#     x: 0.7565781474113464
#     y: 0.43651390075683594
#   }
#   relative_keypoints {
#     x: 1.0845906734466553
#     y: 0.5049386024475098
#   }
# }
# label_id: 0
# score: 0.5301886200904846
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7008510828018188
#     ymin: 0.26853448152542114
#     width: 0.37059807777404785
#     height: 0.4940791130065918
#   }
#   relative_keypoints {
#     x: 0.7599256634712219
#     y: 0.39706045389175415
#   }
#   relative_keypoints {
#     x: 0.8908490538597107
#     y: 0.4331032633781433
#   }
#   relative_keypoints {
#     x: 0.7546756863594055
#     y: 0.5382685661315918
#   }
#   relative_keypoints {
#     x: 0.7703962922096252
#     y: 0.6387123465538025
#   }
#   relative_keypoints {
#     x: 0.7679145336151123
#     y: 0.4174186587333679
#   }
#   relative_keypoints {
#     x: 1.0676170587539673
#     y: 0.489696204662323
#   }
# }
#
# label_id: 0
# score: 0.5240027904510498
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6996346116065979
#     ymin: 0.27091461420059204
#     width: 0.3659164309501648
#     height: 0.4878351092338562
#   }
#   relative_keypoints {
#     x: 0.7640982270240784
#     y: 0.395358145236969
#   }
#   relative_keypoints {
#     x: 0.8860298991203308
#     y: 0.4368578791618347
#   }
#   relative_keypoints {
#     x: 0.7521978616714478
#     y: 0.5354432463645935
#   }
#   relative_keypoints {
#     x: 0.7659936547279358
#     y: 0.6329208016395569
#   }
#   relative_keypoints {
#     x: 0.7749533653259277
#     y: 0.4142424464225769
#   }
#   relative_keypoints {
#     x: 1.0580737590789795
#     y: 0.49870795011520386
#   }
# }
#
# label_id: 0
# score: 0.5895847082138062
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6982405185699463
#     ymin: 0.27046895027160645
#     width: 0.3649570941925049
#     height: 0.4865744113922119
#   }
#   relative_keypoints {
#     x: 0.7586509585380554
#     y: 0.395546555519104
#   }
#   relative_keypoints {
#     x: 0.8837733864784241
#     y: 0.43051785230636597
#   }
#   relative_keypoints {
#     x: 0.7508440613746643
#     y: 0.5341250896453857
#   }
#   relative_keypoints {
#     x: 0.7658010125160217
#     y: 0.6329753398895264
#   }
#   relative_keypoints {
#     x: 0.7684819102287292
#     y: 0.415995717048645
#   }
#   relative_keypoints {
#     x: 1.0503015518188477
#     y: 0.4876710772514343
#   }
# }
#
# label_id: 0
# score: 0.6372720003128052
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7128900289535522
#     ymin: 0.2729420065879822
#     width: 0.3417940139770508
#     height: 0.45570051670074463
#   }
#   relative_keypoints {
#     x: 0.7694697380065918
#     y: 0.38991594314575195
#   }
#   relative_keypoints {
#     x: 0.8912273645401001
#     y: 0.42098116874694824
#   }
#   relative_keypoints {
#     x: 0.7657986879348755
#     y: 0.518375813961029
#   }
#   relative_keypoints {
#     x: 0.7774185538291931
#     y: 0.6116811633110046
#   }
#   relative_keypoints {
#     x: 0.7738924622535706
#     y: 0.410386860370636
#   }
#   relative_keypoints {
#     x: 1.0447760820388794
#     y: 0.47762590646743774
#   }
# }
#
# label_id: 0
# score: 0.6410072445869446
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7152384519577026
#     ymin: 0.26398587226867676
#     width: 0.35033881664276123
#     height: 0.4670920968055725
#   }
#   relative_keypoints {
#     x: 0.7731761932373047
#     y: 0.3848814368247986
#   }
#   relative_keypoints {
#     x: 0.8982797861099243
#     y: 0.41731512546539307
#   }
#   relative_keypoints {
#     x: 0.7699317336082458
#     y: 0.517768144607544
#   }
#   relative_keypoints {
#     x: 0.7824912071228027
#     y: 0.6122751832008362
#   }
#   relative_keypoints {
#     x: 0.7778504490852356
#     y: 0.4032110571861267
#   }
#   relative_keypoints {
#     x: 1.0558671951293945
#     y: 0.47092241048812866
#   }
# }
#
# label_id: 0
# score: 0.6772541999816895
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.718837320804596
#     ymin: 0.2659366726875305
#     width: 0.35446101427078247
#     height: 0.4725855588912964
#   }
#   relative_keypoints {
#     x: 0.7764407396316528
#     y: 0.39295297861099243
#   }
#   relative_keypoints {
#     x: 0.8975337147712708
#     y: 0.4138796925544739
#   }
#   relative_keypoints {
#     x: 0.7734198570251465
#     y: 0.5236668586730957
#   }
#   relative_keypoints {
#     x: 0.7912890315055847
#     y: 0.6192917823791504
#   }
#   relative_keypoints {
#     x: 0.7874247431755066
#     y: 0.4155200719833374
#   }
#   relative_keypoints {
#     x: 1.0600594282150269
#     y: 0.4589872360229492
#   }
# }
#
# label_id: 0
# score: 0.6772541999816895
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.718837320804596
#     ymin: 0.2659366726875305
#     width: 0.35446101427078247
#     height: 0.4725855588912964
#   }
#   relative_keypoints {
#     x: 0.7764407396316528
#     y: 0.39295297861099243
#   }
#   relative_keypoints {
#     x: 0.8975337147712708
#     y: 0.4138796925544739
#   }
#   relative_keypoints {
#     x: 0.7734198570251465
#     y: 0.5236668586730957
#   }
#   relative_keypoints {
#     x: 0.7912890315055847
#     y: 0.6192917823791504
#   }
#   relative_keypoints {
#     x: 0.7874247431755066
#     y: 0.4155200719833374
#   }
#   relative_keypoints {
#     x: 1.0600594282150269
#     y: 0.4589872360229492
#   }
# }
#
# label_id: 0
# score: 0.5462172627449036
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.709613025188446
#     ymin: 0.2385397106409073
#     width: 0.39124220609664917
#     height: 0.5215762257575989
#   }
#   relative_keypoints {
#     x: 0.7814610004425049
#     y: 0.37089020013809204
#   }
#   relative_keypoints {
#     x: 0.920755922794342
#     y: 0.40700018405914307
#   }
#   relative_keypoints {
#     x: 0.7763496041297913
#     y: 0.5163554549217224
#   }
#   relative_keypoints {
#     x: 0.789751410484314
#     y: 0.6240313649177551
#   }
#   relative_keypoints {
#     x: 0.7842803597450256
#     y: 0.3977481722831726
#   }
#   relative_keypoints {
#     x: 1.0913255214691162
#     y: 0.48137611150741577
#   }
# }
#
# label_id: 0
# score: 0.5442749261856079
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.724349856376648
#     ymin: 0.2456197291612625
#     width: 0.3506782054901123
# ...
#     x: 0.8443529605865479
#     y: 0.4579424262046814
#   }
#   relative_keypoints {
#     x: 0.8698982000350952
#     y: 0.5404490828514099
#   }
#   relative_keypoints {
#     x: 0.8091392517089844
#     y: 0.3624175190925598
#   }
#   relative_keypoints {
#     x: 1.0758228302001953
#     y: 0.32237619161605835
#   }
# }
#
# label_id: 0
# score: 0.6868212819099426
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7639119625091553
#     ymin: 0.20755542814731598
#     width: 0.32167792320251465
#     height: 0.4288870096206665
#   }
#   relative_keypoints {
#     x: 0.8126961588859558
#     y: 0.3458736538887024
#   }
#   relative_keypoints {
#     x: 0.931606113910675
#     y: 0.3292914032936096
#   }
#   relative_keypoints {
#     x: 0.8430755138397217
#     y: 0.46113210916519165
#   }
#   relative_keypoints {
#     x: 0.8688998818397522
#     y: 0.5427086353302002
#   }
#   relative_keypoints {
#     x: 0.8071951866149902
#     y: 0.365453839302063
#   }
#   relative_keypoints {
#     x: 1.0736724138259888
#     y: 0.3234349489212036
#   }
# }
#
# label_id: 0
# score: 0.6777332425117493
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7641428709030151
#     ymin: 0.20560674369335175
#     width: 0.3214263916015625
#     height: 0.4285518527030945
#   }
#   relative_keypoints {
#     x: 0.8129491209983826
#     y: 0.34372156858444214
#   }
#   relative_keypoints {
#     x: 0.9301555752754211
#     y: 0.32936370372772217
#   }
#   relative_keypoints {
#     x: 0.8407888412475586
#     y: 0.46084851026535034
#   }
#   relative_keypoints {
#     x: 0.8665419220924377
#     y: 0.5411561131477356
#   }
#   relative_keypoints {
#     x: 0.808893084526062
#     y: 0.36104506254196167
#   }
#   relative_keypoints {
#     x: 1.0734516382217407
#     y: 0.3229815363883972
#   }
# }
#
# label_id: 0
# score: 0.6691205501556396
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7631134390830994
#     ymin: 0.20281334221363068
#     width: 0.3230063319206238
#     height: 0.4306586980819702
#   }
#   relative_keypoints {
#     x: 0.8130745887756348
#     y: 0.3417849540710449
#   }
#   relative_keypoints {
#     x: 0.931575357913971
#     y: 0.3259998559951782
#   }
#   relative_keypoints {
#     x: 0.8425978422164917
#     y: 0.4590792655944824
#   }
#   relative_keypoints {
#     x: 0.8682774305343628
#     y: 0.5404309630393982
#   }
#   relative_keypoints {
#     x: 0.807031512260437
#     y: 0.35993725061416626
#   }
#   relative_keypoints {
#     x: 1.074103832244873
#     y: 0.31935638189315796
#   }
# }
#
# label_id: 0
# score: 0.6996129155158997
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7631052732467651
#     ymin: 0.2061026245355606
#     width: 0.31898319721221924
#     height: 0.4252941608428955
#   }
#   relative_keypoints {
#     x: 0.811007559299469
#     y: 0.34333717823028564
#   }
#   relative_keypoints {
#     x: 0.9273794293403625
#     y: 0.32831448316574097
#   }
#   relative_keypoints {
#     x: 0.8385075926780701
#     y: 0.4596136808395386
#   }
#   relative_keypoints {
#     x: 0.8646271824836731
#     y: 0.5397407412528992
#   }
#   relative_keypoints {
#     x: 0.8077712059020996
#     y: 0.3606632351875305
#   }
#   relative_keypoints {
#     x: 1.0705406665802002
#     y: 0.3213207721710205
#   }
# }
#
# label_id: 0
# score: 0.7081086039543152
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7618850469589233
#     ymin: 0.20790882408618927
#     width: 0.3210113048553467
#     height: 0.4279981255531311
#   }
#   relative_keypoints {
#     x: 0.8100655674934387
#     y: 0.3451916575431824
#   }
#   relative_keypoints {
#     x: 0.9276678562164307
#     y: 0.3295934200286865
#   }
#   relative_keypoints {
#     x: 0.8381021618843079
#     y: 0.4607425332069397
#   }
#   relative_keypoints {
#     x: 0.8642313480377197
#     y: 0.5422399640083313
#   }
#   relative_keypoints {
#     x: 0.8064182996749878
#     y: 0.364104688167572
#   }
#   relative_keypoints {
#     x: 1.0714560747146606
#     y: 0.3245832920074463
#   }
# }
#
# label_id: 0
# score: 0.7448845505714417
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7620463967323303
#     ymin: 0.2102932184934616
#     width: 0.3194851279258728
#     height: 0.42596352100372314
#   }
#   relative_keypoints {
#     x: 0.8106726408004761
#     y: 0.3456176519393921
#   }
#   relative_keypoints {
#     x: 0.9291129112243652
#     y: 0.33295828104019165
#   }
#   relative_keypoints {
#     x: 0.8393276333808899
#     y: 0.4611836075782776
#   }
#   relative_keypoints {
#     x: 0.8637603521347046
#     y: 0.5419303774833679
#   }
#   relative_keypoints {
#     x: 0.8049584031105042
#     y: 0.3637958765029907
#   }
#   relative_keypoints {
#     x: 1.0700172185897827
#     y: 0.33082181215286255
#   }
# }
#
# label_id: 0
# score: 0.7261497378349304
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7606896758079529
#     ymin: 0.20860888063907623
#     width: 0.3230758309364319
#     height: 0.43075114488601685
#   }
#   relative_keypoints {
#     x: 0.8087977170944214
#     y: 0.3476223349571228
#   }
#   relative_keypoints {
#     x: 0.927409827709198
#     y: 0.33037179708480835
#   }
#   relative_keypoints {
#     x: 0.8379522562026978
#     y: 0.46203088760375977
#   }
#   relative_keypoints {
#     x: 0.8645457625389099
#     y: 0.543971598148346
#   }
#   relative_keypoints {
#     x: 0.8055979013442993
#     y: 0.36766713857650757
#   }
#   relative_keypoints {
#     x: 1.0719164609909058
#     y: 0.3255158066749573
#   }
# }
#
# label_id: 0
# score: 0.7496874332427979
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7581604719161987
#     ymin: 0.20827563107013702
#     width: 0.326482892036438
#     height: 0.43529391288757324
#   }
#   relative_keypoints {
#     x: 0.8118734955787659
#     y: 0.3449166417121887
#   }
#   relative_keypoints {
#     x: 0.9339002966880798
#     y: 0.3332473039627075
#   }
#   relative_keypoints {
#     x: 0.843207836151123
#     y: 0.4613659977912903
#   }
#   relative_keypoints {
#     x: 0.8650802373886108
#     y: 0.54459547996521
#   }
#   relative_keypoints {
#     x: 0.8011683225631714
#     y: 0.3649442791938782
#   }
#   relative_keypoints {
#     x: 1.0705316066741943
#     y: 0.33776772022247314
#   }
# }
#
# label_id: 0
# score: 0.7288908362388611
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7581315636634827
#     ymin: 0.2060377150774002
#     width: 0.32771700620651245
#     height: 0.4369390606880188
#   }
#   relative_keypoints {
#     x: 0.8086115121841431
#     y: 0.3474763035774231
#   }
#   relative_keypoints {
#     x: 0.928391695022583
#     y: 0.3300604820251465
#   }
#   relative_keypoints {
#     x: 0.8384835720062256
#     y: 0.46326857805252075
#   }
#   relative_keypoints {
#     x: 0.8644152283668518
#     y: 0.5460979342460632
#   }
#   relative_keypoints {
#     x: 0.8043740391731262
#     y: 0.367656946182251
#   }
#   relative_keypoints {
#     x: 1.0718528032302856
#     y: 0.32672733068466187
#   }
# }
#
# label_id: 0
# score: 0.752746045589447
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7585025429725647
#     ymin: 0.2049650400876999
#     width: 0.3293401598930359
#     height: 0.4391029477119446
#   }
#   relative_keypoints {
#     x: 0.810707688331604
#     y: 0.34628748893737793
#   }
#   relative_keypoints {
#     x: 0.9324584007263184
#     y: 0.32992619276046753
#   }
#   relative_keypoints {
#     x: 0.8421209454536438
#     y: 0.462738573551178
#   }
#   relative_keypoints {
#     x: 0.8668851256370544
#     y: 0.5456385612487793
#   }
#   relative_keypoints {
#     x: 0.8033807277679443
#     y: 0.36662453413009644
#   }
#   relative_keypoints {
#     x: 1.0735610723495483
#     y: 0.3285478949546814
#   }
# }
#
# label_id: 0
# score: 0.7172737717628479
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7589089870452881
#     ymin: 0.2039874941110611
#     width: 0.32887065410614014
#     height: 0.43847692012786865
#   }
#   relative_keypoints {
#     x: 0.809951663017273
#     y: 0.34429603815078735
#   }
#   relative_keypoints {
#     x: 0.9302380084991455
#     y: 0.32910650968551636
#   }
#   relative_keypoints {
#     x: 0.8392429351806641
#     y: 0.4618242383003235
#   }
#   relative_keypoints {
#     x: 0.8646993041038513
#     y: 0.5451835989952087
#   }
#   relative_keypoints {
#     x: 0.8047522306442261
#     y: 0.36392998695373535
#   }
#   relative_keypoints {
#     x: 1.0741301774978638
#     y: 0.32671934366226196
#   }
# }
#
# label_id: 0
# score: 0.7565930485725403
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7578666806221008
#     ymin: 0.20331300795078278
#     width: 0.330000102519989
#     height: 0.4399834871292114
#   }
#   relative_keypoints {
#     x: 0.8101528882980347
#     y: 0.345136821269989
#   }
#   relative_keypoints {
#     x: 0.9334863424301147
#     y: 0.33216148614883423
#   }
#   relative_keypoints {
#     x: 0.8418717980384827
#     y: 0.46414774656295776
#   }
#   relative_keypoints {
#     x: 0.8653673529624939
#     y: 0.5457780957221985
#   }
#   relative_keypoints {
#     x: 0.8017354607582092
#     y: 0.36201047897338867
#   }
#   relative_keypoints {
#     x: 1.0731689929962158
#     y: 0.33100706338882446
#   }
# }
# label_id: 0
# score: 0.7197904586791992
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7583907246589661
#     ymin: 0.20204778015613556
#     width: 0.33327585458755493
#     height: 0.44435036182403564
#   }
#   relative_keypoints {
#     x: 0.8114134669303894
#     y: 0.3425357937812805
#   }
#   relative_keypoints {
#     x: 0.935666024684906
#     y: 0.3293301463127136
#   }
#   relative_keypoints {
#     x: 0.8430070281028748
#     y: 0.46183156967163086
#   }
#   relative_keypoints {
#     x: 0.8670926094055176
#     y: 0.5466975569725037
#   }
#   relative_keypoints {
#     x: 0.8023177981376648
#     y: 0.3628721833229065
#   }
#   relative_keypoints {
#     x: 1.078214168548584
#     y: 0.3298288583755493
#   }
# }
#
# label_id: 0
# score: 0.7679304480552673
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7579755783081055
#     ymin: 0.20037539303302765
#     width: 0.33365797996520996
#     height: 0.44486021995544434
#   }
#   relative_keypoints {
#     x: 0.8109358549118042
#     y: 0.34149259328842163
#   }
#   relative_keypoints {
#     x: 0.934762716293335
#     y: 0.3308669924736023
#   }
#   relative_keypoints {
#     x: 0.841041624546051
#     y: 0.4621691107749939
#   }
#   relative_keypoints {
#     x: 0.8647409081459045
#     y: 0.5454027056694031
#   }
#   relative_keypoints {
#     x: 0.8031757473945618
#     y: 0.35899507999420166
#   }
#   relative_keypoints {
#     x: 1.077323317527771
#     y: 0.3315744400024414
#   }
# }
#
# label_id: 0
# score: 0.7512621879577637
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7576044797897339
#     ymin: 0.200111523270607
#     width: 0.3348008394241333
#     height: 0.44638383388519287
#   }
#   relative_keypoints {
#     x: 0.8122096657752991
#     y: 0.34232980012893677
#   }
#   relative_keypoints {
#     x: 0.9388893246650696
#     y: 0.33042335510253906
#   }
#   relative_keypoints {
#     x: 0.8460942506790161
#     y: 0.4627573490142822
#   }
#   relative_keypoints {
#     x: 0.8686258792877197
#     y: 0.5465938448905945
#   }
#   relative_keypoints {
#     x: 0.8000389933586121
#     y: 0.36022478342056274
#   }
#   relative_keypoints {
#     x: 1.0774812698364258
#     y: 0.33187514543533325
#   }
# }
#
# label_id: 0
# score: 0.7133000493049622
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.758211076259613
#     ymin: 0.20027880370616913
#     width: 0.3345039486885071
#     height: 0.4459880590438843
#   }
#   relative_keypoints {
#     x: 0.8095715641975403
#     y: 0.34472179412841797
#   }
#   relative_keypoints {
#     x: 0.9332744479179382
#     y: 0.32880258560180664
#   }
#   relative_keypoints {
#     x: 0.8405481576919556
#     y: 0.46441948413848877
#   }
#   relative_keypoints {
#     x: 0.8665287494659424
#     y: 0.548302948474884
#   }
#   relative_keypoints {
#     x: 0.8033196926116943
#     y: 0.36324751377105713
#   }
#   relative_keypoints {
#     x: 1.079174280166626
#     y: 0.3241594433784485
#   }
# }
#
# label_id: 0
# score: 0.7362809181213379
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7573238611221313
#     ymin: 0.1986953467130661
#     width: 0.33506155014038086
#     height: 0.4467311501502991
#   }
#   relative_keypoints {
#     x: 0.8098294138908386
#     y: 0.3388904333114624
#   }
#   relative_keypoints {
#     x: 0.9321156144142151
#     y: 0.32838088274002075
#   }
#   relative_keypoints {
#     x: 0.8373438119888306
#     y: 0.4605969786643982
#   }
#   relative_keypoints {
#     x: 0.8620165586471558
#     y: 0.545558512210846
#   }
#   relative_keypoints {
#     x: 0.8047379851341248
#     y: 0.3577355742454529
#   }
#   relative_keypoints {
#     x: 1.0777981281280518
#     y: 0.3301730751991272
#   }
# }
#
# label_id: 0
# score: 0.7362809181213379
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7573238611221313
#     ymin: 0.1986953467130661
#     width: 0.33506155014038086
#     height: 0.4467311501502991
#   }
#   relative_keypoints {
#     x: 0.8098294138908386
#     y: 0.3388904333114624
#   }
#   relative_keypoints {
#     x: 0.9321156144142151
#     y: 0.32838088274002075
#   }
#   relative_keypoints {
#     x: 0.8373438119888306
#     y: 0.4605969786643982
#   }
#   relative_keypoints {
#     x: 0.8620165586471558
#     y: 0.545558512210846
#   }
#   relative_keypoints {
#     x: 0.8047379851341248
#     y: 0.3577355742454529
#   }
#   relative_keypoints {
#     x: 1.0777981281280518
#     y: 0.3301730751991272
#   }
# }
#
# label_id: 0
# score: 0.723131537437439
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.756172239780426
#     ymin: 0.1945890635251999
#     width: 0.3365491032600403
#     height: 0.44871407747268677
#   }
#   relative_keypoints {
#     x: 0.8068806529045105
#     y: 0.33877450227737427
#   }
#   relative_keypoints {
#     x: 0.9262940287590027
#     y: 0.32521575689315796
#   }
#   relative_keypoints {
#     x: 0.8316596746444702
#     y: 0.46132761240005493
#   }
#   relative_keypoints {
#     x: 0.8591423034667969
#     y: 0.5453134179115295
#   }
#   relative_keypoints {
#     x: 0.8079425096511841
#     y: 0.3554852604866028
#   }
#   relative_keypoints {
#     x: 1.0778177976608276
#     y: 0.320822536945343
#   }
# }
#
# label_id: 0
# score: 0.7025406360626221
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7557898759841919
#     ymin: 0.19704385101795197
#     width: 0.334003210067749
#     height: 0.44532084465026855
#   }
#   relative_keypoints {
#     x: 0.8068132996559143
#     y: 0.3398507833480835
#   }
#   relative_keypoints {
#     x: 0.924314558506012
#     y: 0.32684260606765747
#   }
#   relative_keypoints {
#     x: 0.8299370408058167
#     y: 0.46145009994506836
#   }
#   relative_keypoints {
#     x: 0.8569546937942505
#     y: 0.5445294976234436
#   }
#   relative_keypoints {
#     x: 0.8084774017333984
#     y: 0.3559797406196594
#   }
#   relative_keypoints {
#     x: 1.075207233428955
#     y: 0.323308527469635
#   }
# }
#
# label_id: 0
# score: 0.7570406198501587
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7593802809715271
#     ymin: 0.2017797976732254
#     width: 0.32459086179733276
#     height: 0.4327709674835205
#   }
#   relative_keypoints {
#     x: 0.8064923286437988
#     y: 0.34034305810928345
#   }
#   relative_keypoints {
#     x: 0.9227259159088135
#     y: 0.3287891745567322
#   }
#   relative_keypoints {
#     x: 0.8293420672416687
#     y: 0.4597131013870239
#   }
#   relative_keypoints {
#     x: 0.8562394380569458
#     y: 0.5402486324310303
#   }
#   relative_keypoints {
#     x: 0.8082046508789062
#     y: 0.35476934909820557
#   }
#   relative_keypoints {
#     x: 1.0713932514190674
#     y: 0.32378435134887695
#   }
# }
#
# label_id: 0
# score: 0.724151074886322
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.7588854432106018
#     ymin: 0.1959114521741867
#     width: 0.3294551968574524
#     height: 0.4392566680908203
#   }
#   relative_keypoints {
#     x: 0.8059287667274475
#     y: 0.3358690142631531
#   }
#   relative_keypoints {
#     x: 0.9223935604095459
#     y: 0.32359081506729126
#   }
#   relative_keypoints {
#     x: 0.8265938758850098
#     y: 0.45622217655181885
#   }
#   relative_keypoints {
#     x: 0.854537844657898
#     y: 0.5393645763397217
#   }
#   relative_keypoints {
#     x: 0.8105367422103882
#     y: 0.35142576694488525
#   }
#   relative_keypoints {
#     x: 1.0753623247146606
#     y: 0.32020658254623413
#   }
# }
